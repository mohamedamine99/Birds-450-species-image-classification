# %%
import os
import shutil
import matplotlib.pyplot as plt
from PIL import Image
import random
import time
import numpy as np
import pandas as pd
import cv2

# %%
os.listdir("/kaggle/working")
# Out:
# ['__notebook_source__.ipynb',
#  '.virtual_documents',
#  'state.db',
#  'log_class_weights.csv',
#  'log.csv',
#  'Models_class_weights',
#  'Models']

# %%
images_to_test_path = '/kaggle/input/100-bird-species/images to test'
test_path = '/kaggle/input/100-bird-species/test'
train_path ='/kaggle/input/100-bird-species/train'
validation_path = '/kaggle/input/100-bird-species/valid'

# %%
print(len(os.listdir(images_to_test_path)))
print(len(os.listdir(test_path)))
print(len(os.listdir(train_path)))
print(len(os.listdir(validation_path)))
# Out:
# 5
# 450
# 450
# 450

# %%
def print_stats(path = '', verbose = False):
    sizes = []
    i = 0
    for filename in os.listdir(path):
        i+=1
        size = len(os.listdir(path + '/' + filename))
        sizes.append(size)
        if verbose == True :
            print(size , end = " ")
            if (i% 20 == 0):
                print()
    print()

    print("Max samples = {}".format(max(sizes)))
    print("Min samples = {}".format(min(sizes)))
    print("sum samples = {}".format(sum(sizes)))
    print("Average sample size = {}".format(np.mean(sizes)))
    print("Sample sizes standard deviation = {}".format(np.std(sizes)))

    return sizes

# %%
print('validation set stats :')
sizes = print_stats(validation_path)
print('\n*********************')
print('testing set stats :')
sizes = print_stats(test_path)
# Out:
# validation set stats :
#
# Max samples = 5
# Min samples = 5
# sum samples = 2250
# Average sample size = 5.0
# Sample sizes standard deviation = 0.0
#
# *********************
# testing set stats :
#
# Max samples = 5
# Min samples = 5
# sum samples = 2250
# Average sample size = 5.0
# Sample sizes standard deviation = 0.0

# %%
sizes = print_stats(train_path , verbose = True)
# Out:
# 159 138 187 162 153 155 155 133 139 187 135 155 160 155 154 202 163 183 137 176
# 194 152 158 136 165 151 179 161 154 135 153 161 200 135 155 155 153 154 132 136
# 161 163 144 154 161 161 152 154 162 135 164 142 159 179 157 163 160 197 133 192
# 157 131 155 160 156 165 141 139 184 137 168 156 143 132 169 164 138 140 159 135
# 155 142 132 170 160 213 139 166 136 136 144 132 138 156 170 142 131 133 154 150
# 184 165 217 176 233 152 134 154 154 172 157 157 154 175 150 152 248 130 158 158
# 166 155 160 133 166 140 154 194 156 139 144 154 175 160 168 164 144 133 139 185
# 154 130 160 151 155 162 163 130 154 167 154 190 154 144 169 165 149 152 138 150
# 164 166 163 168 154 152 162 160 154 143 149 154 138 137 152 159 154 166 150 155
# 163 136 175 154 166 186 138 162 144 164 167 155 152 154 150 167 132 159 154 132
# 132 141 144 142 170 164 154 131 188 177 160 175 155 144 153 134 156 141 157 135
# 154 164 155 150 140 153 144 165 188 180 136 151 160 166 173 155 163 177 157 163
# 197 153 160 143 141 156 161 152 141 163 154 150 182 161 160 142 197 166 165 140
# 163 163 154 160 155 160 190 162 143 164 139 163 147 152 160 161 155 161 153 157
# 155 141 196 179 144 160 181 177 158 158 188 133 160 137 144 163 154 140 201 154
# 160 150 154 156 150 142 162 189 163 156 139 160 185 137 159 203 190 161 138 141
# 132 159 144 132 184 153 187 153 165 233 207 193 161 160 153 160 198 134 155 155
# 154 138 163 186 190 164 155 133 164 168 136 139 155 153 160 162 162 177 137 150
# 157 153 163 142 137 154 159 173 167 163 154 160 141 150 214 155 167 151 139 153
# 152 160 135 154 139 156 164 131 143 156 152 160 160 153 175 161 137 138 135 161
# 155 157 150 175 137 180 137 141 163 150 158 134 138 159 150 132 133 160 154 143
# 160 156 160 164 159 156 165 173 146 176 186 164 143 165 155 131 163 144 132 160
# 137 162 153 160 157 135 139 135 135 162
# Max samples = 248
# Min samples = 130
# sum samples = 70626
# Average sample size = 156.94666666666666
# Sample sizes standard deviation = 17.388675753042392

# %%
df = pd.read_csv('/kaggle/input/100-bird-species/birds.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75126 entries, 0 to 75125
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   class id          75126 non-null  int64
#  1   filepaths         75126 non-null  object
#  2   labels            75126 non-null  object
#  3   scientific label  75126 non-null  object
#  4   data set          75126 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.9+ MB

# %%
df.sample(frac = 1).head()
# Out:
#        class id                       filepaths            labels  \
# 43550       278               train/IWI/044.jpg               IWI
# 68458       436   train/WATTLED LAPWING/070.jpg   WATTLED LAPWING
# 30013       191      train/ENGGANO MYNA/106.jpg      ENGGANO MYNA
# 72610       396                 test/SORA/5.jpg              SORA
# 55429       353  train/RAINBOW LORIKEET/138.jpg  RAINBOW LORIKEET
#
#                scientific label data set
# 43550       Vestiaria coccinea.    train
# 68458          Vanellus indicus    train
# 30013        Gracula enganensis    train
# 72610          Porzana carolina     test
# 55429  Trichoglossus moluccanus    train

# %%
def display_samples(path = '', ncols = 1, nrows= 1 , verbose = False):
    
    
    imgs = []
    classes = random.sample(os.listdir(path), ncols * nrows)
    imgs_idx = [random.randint(0,len(os.listdir(path + '/'+ class_name))-1) 
            for class_name in classes]
    for i, img_idx in enumerate(imgs_idx):
        imgs.append(path + '/' + classes[i] + '/' +
                    os.listdir(path + '/' + classes[i])[img_idx])

    if verbose :    
        print(classes)
        print()
        print(imgs_idx)
        print()
        print(imgs)

    i = 0
    fig = plt.figure(figsize=(10, 10))
    # Adds a subplot at the 1st position
    for i in range(len(imgs)):
        fig.add_subplot(nrows, ncols, i + 1)
        img = cv2.imread(imgs[i])
    # showing image
        plt.imshow(img)
        plt.axis('off')
        plt.title(classes[i],fontsize = 10)

# %%
display_samples(train_path, 5 ,5)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fdcfcfa6b00> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2844             self.patch.draw(renderer)
#    2845             mimage._draw_list_compositing_images(
# -> 2846                 renderer, self, artists, self.suppressComposite)
#    2847
#    2848             for sfig in self.subfigs:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3053                 artists.remove(spine)
#    3054
# -> 3055         self._update_title_position(renderer)
#    3056
#    3057         if not self.axison:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    3003                 _log.debug('top of Axes not in the figure, so title not moved')
#    3004                 return
# -> 3005             if title.get_window_extent(renderer).ymin < top:
#    3006                 _, y = self.transAxes.inverted().transform((0, top))
#    3007                 title.set_position((x, y))
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     898             with cbook._setattr_cm(self.figure, dpi=dpi):
#     899                 tx, ty = self._get_xy_display()
# --> 900                 return Bbox.from_bounds(tx, ty, 0, 0)
#     901
#     902         if renderer is not None:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in from_bounds(x0, y0, width, height)
#     818         *width* and *height* may be negative.
#     819         """
# --> 820         return Bbox.from_extents(x0, y0, x0 + width, y0 + height)
#     821
#     822     @staticmethod
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in from_extents(minpos, *args)
#     837            scales where negative bounds result in floating point errors.
#     838         """
# --> 839         bbox = Bbox(np.reshape(args, (2, 2)))
#     840         if minpos is not None:
#     841             bbox._minpos[:] = minpos
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#     299
#     300
#
# KeyboardInterrupt:

# %%
display_samples(test_path, 5 ,5)

# %%
display_samples(validation_path, 5 ,5)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        shear_range = 0.1,
        horizontal_flip=True,
        brightness_range=(0.9,1.1),
        rescale=1./255,
        fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
BATCH = 64
train_augmented = train_datagen.flow_from_directory(
    directory = train_path,
    target_size=(150, 150),
    color_mode='rgb',
    classes=None,
    class_mode='categorical',
    batch_size=BATCH,
    shuffle=True,
    seed=1,
    interpolation='nearest'
)

#print(train_augmented.class_indices)
# Out:
# Found 70626 images belonging to 450 classes.

# %%
test_augmented = test_datagen.flow_from_directory(
    directory = test_path,
    target_size=(150, 150),
    color_mode='rgb',
    classes=None,
    class_mode='categorical',
    batch_size=BATCH,
    shuffle=True,
    seed=1,
    interpolation='nearest'
)
# Out:
# Found 2250 images belonging to 450 classes.

# %%
validation_augmented = validation_datagen.flow_from_directory(
    directory = validation_path,
    target_size=(150, 150),
    color_mode='rgb',
    classes=None,
    class_mode='categorical',
    batch_size=BATCH,
    shuffle=True,
    seed=1,
    interpolation='nearest'
)
# Out:
# Found 2250 images belonging to 450 classes.

# %%
from sklearn.utils import class_weight

# %%
# Compute class weights
class_weights = class_weight.compute_class_weight(
    class_weight = 'balanced',
    classes = np.unique(train_augmented.classes),
    y = train_augmented.classes)
print(type(class_weights))
print(class_weights.shape)
# Out:
# <class 'numpy.ndarray'>
# (450,)

# %%
class_weight_dict = dict(enumerate(class_weights))
print(class_weight_dict)
# Out:
# {0: 0.9454618473895582, 1: 0.8719259259259259, 2: 0.8767970204841713, 3: 1.145596107055961, 4: 1.0191341991341991, 5: 1.145596107055961, 6: 1.0125591397849463, 7: 0.8392869875222816, 8: 1.1800501253132831, 9: 0.974824016563147, 10: 0.9511919191919191, 11: 0.9454618473895582, 12: 1.0463111111111112, 13: 0.8767970204841713, 14: 0.9232156862745098, 15: 0.9933333333333333, 16: 0.9569918699186992, 17: 1.1800501253132831, 18: 1.0125591397849463, 19: 0.8767970204841713, 20: 1.1291127098321343, 21: 0.8392869875222816, 22: 1.1980661577608143, 23: 1.1712437810945273, 24: 1.0899074074074073, 25: 1.0191341991341991, 26: 1.0191341991341991, 27: 1.0463111111111112, 28: 1.1291127098321343, 29: 1.0463111111111112, 30: 1.1291127098321343, 31: 1.0191341991341991, 32: 1.0257952069716776, 33: 1.0125591397849463, 34: 0.834822695035461, 35: 0.9569918699186992, 36: 0.9996602972399151, 37: 1.1130969267139479, 38: 0.8392869875222816, 39: 1.0191341991341991, 40: 0.8260350877192982, 41: 0.9569918699186992, 42: 0.9342063492063492, 43: 1.1130969267139479, 44: 1.1540196078431373, 45: 1.145596107055961, 46: 0.9511919191919191, 47: 1.0463111111111112, 48: 0.9809166666666667, 49: 1.0191341991341991, 50: 1.188989898989899, 51: 1.145596107055961, 52: 0.9454618473895582, 53: 0.9628629856850716, 54: 0.8090034364261168, 55: 0.9454618473895582, 56: 1.0125591397849463, 57: 0.9342063492063492, 58: 0.9809166666666667, 59: 1.188989898989899, 60: 1.1540196078431373, 61: 1.188989898989899, 62: 1.0975291375291376, 63: 0.9809166666666667, 64: 1.1052582159624413, 65: 1.0899074074074073, 66: 1.0191341991341991, 67: 1.0325438596491228, 68: 1.1052582159624413, 69: 1.006068376068376, 70: 1.1800501253132831, 71: 1.1980661577608143, 72: 0.9809166666666667, 73: 0.9569918699186992, 74: 0.9511919191919191, 75: 0.9628629856850716, 76: 1.162567901234568, 77: 0.834822695035461, 78: 1.006068376068376, 79: 1.1800501253132831, 80: 1.145596107055961, 81: 0.9342063492063492, 82: 1.1712437810945273, 83: 1.0899074074074073, 84: 1.0257952069716776, 85: 1.0125591397849463, 86: 0.9072061657032755, 87: 0.8483603603603603, 88: 0.9398003992015969, 89: 0.8437992831541219, 90: 1.0463111111111112, 91: 0.9996602972399151, 92: 1.0191341991341991, 93: 0.9809166666666667, 94: 1.0191341991341991, 95: 1.0191341991341991, 96: 0.8529710144927536, 97: 0.8867043314500942, 98: 1.0191341991341991, 99: 0.9511919191919191, 100: 0.8529710144927536, 101: 0.9870859538784067, 102: 1.0975291375291376, 103: 0.9809166666666667, 104: 1.0125591397849463, 105: 0.96880658436214, 106: 1.0257952069716776, 107: 0.9809166666666667, 108: 0.974824016563147, 109: 0.79668358714044, 110: 0.9809166666666667, 111: 1.0191341991341991, 112: 1.1800501253132831, 113: 1.0191341991341991, 114: 1.0125591397849463, 115: 1.145596107055961, 116: 1.1800501253132831, 117: 0.96880658436214, 118: 0.7368388106416276, 119: 0.9569918699186992, 120: 0.8719259259259259, 121: 0.9628629856850716, 122: 1.0257952069716776, 123: 1.145596107055961, 124: 1.188989898989899, 125: 0.9511919191919191, 126: 1.0899074074074073, 127: 0.96880658436214, 128: 1.1130969267139479, 129: 0.9342063492063492, 130: 0.9569918699186992, 131: 0.9628629856850716, 132: 0.9628629856850716, 133: 0.974824016563147, 134: 0.9628629856850716, 135: 0.9454618473895582, 136: 0.8867043314500942, 137: 1.1291127098321343, 138: 0.8867043314500942, 139: 0.9996602972399151, 140: 1.1800501253132831, 141: 0.974824016563147, 142: 0.974824016563147, 143: 1.1130969267139479, 144: 1.0899074074074073, 145: 1.0899074074074073, 146: 1.162567901234568, 147: 1.1291127098321343, 148: 0.9809166666666667, 149: 1.0125591397849463, 150: 1.0257952069716776, 151: 1.1052582159624413, 152: 0.9628629856850716, 153: 1.0325438596491228, 154: 0.9569918699186992, 155: 1.006068376068376, 156: 1.0191341991341991, 157: 0.7926599326599326, 158: 0.9628629856850716, 159: 0.9809166666666667, 160: 0.96880658436214, 161: 1.1372946859903381, 162: 1.145596107055961, 163: 0.6735908440629471, 164: 0.9870859538784067, 165: 1.15401960784 ...

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

mnet_base = MobileNetV2(input_shape = (150,150,3),
                       include_top = False,
                       weights = 'imagenet')

mnet_base.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
#mnet_base.summary()

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import BatchNormalization, Dropout, Dense, GlobalAveragePooling2D, ReLU

# %%
inputs = Input(shape = (150,150,3))
x = mnet_base(inputs)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Dropout(0.25)(x)
x = Dense(2048)(x)

x = BatchNormalization()(x)
x = ReLU()(x)
x = Dropout(0.25)(x)
x = Dense(900)(x)

x = BatchNormalization()(x)
x = ReLU()(x)
x = Dropout(0.25)(x)
outputs = Dense(450,activation = 'softmax')(x)

model = Model(inputs , outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# mobilenetv2_1.00_224 (Functi (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1280)              5120
# _________________________________________________________________
# re_lu (ReLU)                 (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              2623488
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 900)               1844100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 900)               3600
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 900)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 900)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 450)               405450
# =================================================================
# Total params: 7,147,934
# Trainable params: 4,881,494
# Non-trainable params: 2,266,440
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer = Adam(learning_rate = 0.001),
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
models_path = '/kaggle/working/Models_class_weights'
#shutil.rmtree(models_path)
os.makedirs(models_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_23/1881329634.py in <module>
#       1 models_path = '/kaggle/working/Models_class_weights'
#       2 #shutil.rmtree(models_path)
# ----> 3 os.makedirs(models_path)
#
# /opt/conda/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: '/kaggle/working/Models_class_weights'

# %%
from tensorflow.keras.callbacks import  ModelCheckpoint, CSVLogger

checkpoint = ModelCheckpoint(filepath = models_path + '/checkpoint.hdf5',
    monitor = "val_accuracy",
    save_best_only=True,
    save_weights_only=True,
    verbose=1,
    mode = 'max')

filename='log_class_weights.csv'
history_logger= CSVLogger(filename, separator=",", append=True)


callbacks = [checkpoint, history_logger]

# %%
EPOCHS = 15
beg = int(time.time())

history = model.fit(
        train_augmented,
        steps_per_epoch = train_augmented.samples  // BATCH,
        epochs = EPOCHS,
        validation_data = validation_augmented,
        validation_steps = validation_augmented.samples // BATCH,
        class_weight = class_weight_dict,
        callbacks = callbacks)

end = int(time.time())
t = end - beg
hrs = t // 3600
mins = (t - 3600 * hrs) // 60
secs = t % 60
print("training took {} hrs -- {} mins -- {} secs".format(hrs,mins,secs))
model.save_weights(models_path + '/first_try_weights.h5')
model.save(models_path + '/first_try.h5')

# %%
print(os.listdir("/kaggle/working/Models"))
scores = model.evaluate(test_augmented)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.compile(optimizer = Adam(learning_rate = 0.001 * 0.2),
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])
model.summary()

# %%
model.layers[1].trainable = True
for sub_layer in model.layers[1].layers[:-38]:
    sub_layer.trainable = False
    #print(sub_layer.name)

# %%
model.summary()

# %%
beg = int(time.time())

history = model.fit(
        train_augmented,
        steps_per_epoch = train_augmented.samples  // BATCH,
        epochs = EPOCHS,
        validation_data = validation_augmented,
        validation_steps = validation_augmented.samples // BATCH,
        class_weight = class_weight_dict,

        callbacks = callbacks)

end = int(time.time())
t = end - beg
hrs = t // 3600
mins = (t - 3600 * hrs) // 60
secs = t % 60
print("training took {} hrs -- {} mins -- {} secs".format(hrs,mins,secs))
model.save_weights(models_path + '/second_try_weights.h5')
model.save(models_path + '/second_try.h5')

# %%
scores = model.evaluate(test_augmented)

# %%
model.layers[1].trainable = True
for sub_layer in model.layers[1].layers[:-74]:
    sub_layer.trainable = False
    #print(sub_layer.name)

# %%
model.compile(optimizer = Adam(learning_rate = 0.001 * 0.2 * 0.2),
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])
model.summary()

# %%
beg = int(time.time())

history = model.fit(
        train_augmented,
        steps_per_epoch = train_augmented.samples  // BATCH,
        epochs = EPOCHS,
        validation_data = validation_augmented,
        validation_steps = validation_augmented.samples // BATCH,
        class_weight = class_weight_dict,
        callbacks = callbacks)

end = int(time.time())
t = end - beg
hrs = t // 3600
mins = (t - 3600 * hrs) // 60
secs = t % 60
print("training took {} hrs -- {} mins -- {} secs".format(hrs,mins,secs))
model.save_weights(models_path + '/3rd_try_weights.h5')
model.save(models_path + '/3rd_try.h5')

# %%
scores = model.evaluate(test_augmented)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model

# %%
model = load_model('/kaggle/working/Models_class_weights/3rd_try.h5')

# %%
#scores3 = model.evaluate(test_augmented)
model.load_weights('/kaggle/working/Models_class_weights/3rd_try_weights.h5')
scores_3 = model.evaluate(test_augmented)
model.load_weights('/kaggle/working/Models_class_weights/checkpoint.hdf5')
scores_3best = model.evaluate(test_augmented)

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(optimizer = Adam(learning_rate = 0.001 * 0.2 * 0.2),
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import  EarlyStopping, ModelCheckpoint, CSVLogger, ReduceLROnPlateau


models_path = "/kaggle/working/Models_class_weights"
checkpoint = ModelCheckpoint(filepath = models_path + '/checkpoint.hdf5',
    monitor = "val_accuracy",
    save_best_only=True,
    save_weights_only=True,
    verbose=1,
    mode = 'max')

filename='log_class_weights.csv'
history_logger= CSVLogger(filename, separator=",", append=True)

reduce_lro = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.3,
    patience=3,
    verbose=1,
    mode='auto',

)

early_stop  = EarlyStopping(patience = 6)
callbacks = [checkpoint, history_logger, reduce_lro, early_stop]

# %%
beg = int(time.time())

history = model.fit(
        train_augmented,
        steps_per_epoch = train_augmented.samples  // BATCH,
        epochs = 20,
        validation_data = validation_augmented,
        validation_steps = validation_augmented.samples // BATCH,
        class_weight = class_weight_dict,
        callbacks = callbacks)

end = int(time.time())
t = end - beg
hrs = t // 3600
mins = (t - 3600 * hrs) // 60
secs = t % 60
print("training took {} hrs -- {} mins -- {} secs".format(hrs,mins,secs))
model.save_weights(models_path + '/final_try_weights.h5')
model.save(models_path + '/final_try.h5')
# Out:
# Epoch 1/20
# 1103/1103 [==============================] - 894s 808ms/step - loss: 0.2251 - accuracy: 0.9319 - val_loss: 0.2398 - val_accuracy: 0.9353
#
# Epoch 00001: val_accuracy improved from -inf to 0.93527, saving model to /kaggle/working/Models_class_weights/checkpoint.hdf5
# Epoch 2/20
# 1103/1103 [==============================] - 615s 557ms/step - loss: 0.2286 - accuracy: 0.9301 - val_loss: 0.2227 - val_accuracy: 0.9393
#
# Epoch 00002: val_accuracy improved from 0.93527 to 0.93929, saving model to /kaggle/working/Models_class_weights/checkpoint.hdf5
# Epoch 3/20
# 1103/1103 [==============================] - 619s 561ms/step - loss: 0.2224 - accuracy: 0.9319 - val_loss: 0.2256 - val_accuracy: 0.9384
#
# Epoch 00003: val_accuracy did not improve from 0.93929
# Epoch 4/20
# 1103/1103 [==============================] - 616s 559ms/step - loss: 0.2133 - accuracy: 0.9344 - val_loss: 0.2050 - val_accuracy: 0.9415
#
# Epoch 00004: val_accuracy improved from 0.93929 to 0.94152, saving model to /kaggle/working/Models_class_weights/checkpoint.hdf5
# Epoch 5/20
# 1103/1103 [==============================] - 639s 579ms/step - loss: 0.2086 - accuracy: 0.9355 - val_loss: 0.2108 - val_accuracy: 0.9402
#
# Epoch 00005: val_accuracy did not improve from 0.94152
# Epoch 6/20
# 1103/1103 [==============================] - 637s 578ms/step - loss: 0.2098 - accuracy: 0.9364 - val_loss: 0.2127 - val_accuracy: 0.9402
#
# Epoch 00006: val_accuracy did not improve from 0.94152
# Epoch 7/20
# 1103/1103 [==============================] - 630s 571ms/step - loss: 0.1974 - accuracy: 0.9389 - val_loss: 0.2222 - val_accuracy: 0.9379
#
# Epoch 00007: val_accuracy did not improve from 0.94152
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.1999999696854501e-05.
# Epoch 8/20
# 1103/1103 [==============================] - 613s 555ms/step - loss: 0.1852 - accuracy: 0.9433 - val_loss: 0.1973 - val_accuracy: 0.9442
#
# Epoch 00008: val_accuracy improved from 0.94152 to 0.94420, saving model to /kaggle/working/Models_class_weights/checkpoint.hdf5
# Epoch 9/20
# 1103/1103 [==============================] - 607s 550ms/step - loss: 0.1737 - accuracy: 0.9457 - val_loss: 0.1925 - val_accuracy: 0.9411
#
# Epoch 00009: val_accuracy did not improve from 0.94420
# Epoch 10/20
# 1103/1103 [==============================] - 605s 549ms/step - loss: 0.1690 - accuracy: 0.9486 - val_loss: 0.1934 - val_accuracy: 0.9415
#
# Epoch 00010: val_accuracy did not improve from 0.94420
# Epoch 11/20
# 1103/1103 [==============================] - 603s 547ms/step - loss: 0.1692 - accuracy: 0.9480 - val_loss: 0.1966 - val_accuracy: 0.9433
#
# Epoch 00011: val_accuracy did not improve from 0.94420
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.5999998544866682e-06.
# Epoch 12/20
# 1103/1103 [==============================] - 609s 552ms/step - loss: 0.1611 - accuracy: 0.9504 - val_loss: 0.1983 - val_accuracy: 0.9438
#
# Epoch 00012: val_accuracy did not improve from 0.94420
# Epoch 13/20
# 1103/1103 [==============================] - 614s 556ms/step - loss: 0.1594 - accuracy: 0.9507 - val_loss: 0.1962 - val_accuracy: 0.9424
#
# Epoch 00013: val_accuracy did not improve from 0.94420
# Epoch 14/20
# 1103/1103 [==============================] - 607s 551ms/step - loss: 0.1597 - accuracy: 0.9511 - val_loss: 0.1973 - val_accuracy: 0.9433
#
# Epoch 00014: val_accuracy did not improve from 0.94420
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.079999969988421e-06.
# Epoch 15/20
# 1103/1103 [==============================] - 606s 550ms/step - loss: 0.1553 - accuracy: 0.9526 - val_loss: 0.1965 - val_accuracy: 0.9424
#
# Epoch 00015: val_accuracy did not improve from 0.94420
# training took 2 hrs -- 41 mins -- 41 secs
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
model = load_model('/kaggle/working/Models_class_weights/final_try.h5')
# Out:
# 2023-01-19 20:16:47.487545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:47.596779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:47.597931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:47.600077: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-19 20:16:47.600440: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:47.601400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:47.602387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:50.149394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:50.150524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:50.151467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 20:16:50.152300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
scores = model.evaluate(test_augmented)
# Out:
# 36/36 [==============================] - 7s 208ms/step - loss: 0.1276 - accuracy: 0.9609

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
